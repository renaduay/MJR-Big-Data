# %% [markdown]
# <a href="https://colab.research.google.com/github/renaduay/MJR-Big-Data/blob/main/Python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Big Data
#
# # pandas data frame

# %%
import pandas as pd
from google.colab import files

# %%
d_star_wars = pd.read_csv(filepath_or_buffer="https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv", sep=',')
d_star_wars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species
# 0     male  Tatooine   Human
# 1      NaN  Tatooine   Droid
# 2      NaN     Naboo   Droid
# 3     male  Tatooine   Human
# 4   female  Alderaan   Human
# ..     ...       ...     ...
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
# 86  female     Naboo   Human
#
# [87 rows x 10 columns]

# %%
#Mostrar todas las columas del dataframa
d_star_wars.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9ea9baa12301> in <cell line: 2>()
#       1 #Mostrar todas las columas del dataframa
# ----> 2 d_star_wars.columns
#
# NameError: name 'd_star_wars' is not defined

# %% [markdown]
# ### 1) ¿Cómo eliminar columnas?

# %%
# Una columna
d_star_wars.drop(columns='name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4c085dc59622> in <cell line: 2>()
#       1 # Una columna
# ----> 2 d_star_wars.drop(columns='name')
#
# NameError: name 'd_star_wars' is not defined

# %%
# Eliminar N columnas
d_star_wars.drop(columns=['name', 'height'])

# %% [markdown]
# ### 2) ¿Cómo eliminar duplicados?

# %%
d_star_wars_2 = d_star_wars[['hair_color',	'skin_color']]

d_star_wars_2

# %%
d_star_wars_3=d_star_wars_2.drop_duplicates()

d_star_wars_3

# %%
d_star_wars_3.shape

# %% [markdown]
# 2.b) ¿Cómo obtener los registros duplicados?

# %%
d_star_wars_2[d_star_wars_2.duplicated()]

# %%
d_star_wars_2[d_star_wars_2.duplicated()].shape

# %% [markdown]
# ### 3) ¿Cómo ordenar un data frame?

# %%
d_star_wars.sort_values('birth_year') # analizar los últimos valores...

# %%
# Orden descendente
d_star_wars.sort_values('birth_year', ascending=False)

# %%
from google.colab.data_table import DataTable

# Ordenar por dos columnas
DataTable(d_star_wars.sort_values(['species', 'birth_year']))

# %%
# Emprolijar para chequear
d_sw_ordenado=d_star_wars.sort_values(['species', 'birth_year'])

# %%
# Comprobamos que están ordenados
d_sw_ordenado=d_sw_ordenado[['species', 'birth_year']]

DataTable(d_sw_ordenado)

# %% [markdown]
# ### 4) ¿Cómo crear una variable en un dataframe?

# %%
d_star_wars['nueva_variable']=999

d_star_wars

# %%
# Pasando a metros la altura
d_star_wars['height_mts']=d_star_wars['height']/100

d_star_wars.head()

# %% [markdown]
# ### 5) ¿Cómo reordenar variables en un pandas data frame?

# %%
# Tomo las 3 priemras columnas (name, height, mass)
d_star_wars_4=d_star_wars.iloc[:, 0:3]
d_star_wars_4.columns

# %%
# reorden
d_star_wars_5=d_star_wars_4[['mass', 'height', 'name']]

# %%
d_star_wars_5

# %% [markdown]
# ### 6) ¿Cómo renombrar variables?

# %%
d_star_wars_5.head()

# %%
d_star_wars_5.rename(columns={'mass':'peso', 'height':'altura', 'name':'nombre'}).head()

# %%
# Aplicar función a todas las columnas. Todo a minúscula o mayúscula

d_star_wars_5.rename(str.upper, axis="columns").head()

# %% [markdown]
# Eliminar espacios de las columnas

# %%
d_star_wars_6=d_star_wars_5.rename(columns={'mass':'peso del personaje', 'height':'altura del personaje'})
d_star_wars_6.head()

# %%
d_star_wars_6.columns = d_star_wars_6.columns.str.replace(' ', '_')

d_star_wars_6.head()

# %% [markdown]
# ### 7)  ¿Cómo filtrar datos con pandas query?

# %%
d_star_wars.query(" height > 220 ")

# %%
# AND
d_star_wars.query(" height > 220 and hair_color == 'brown' ")

# %%
# OR, filtrar extremos
d_star_wars.query("height < 150 or height > 220 ")

# %% [markdown]
# ### 8) Descripción estadística básica

# %%
#Instalamos funpymodeling para obtener estadística de los datos

# %%capture
# !pip install funpymodeling

# %%
#importamos la librería para poder utilizarla
from funpymodeling.exploratory import status, freq_tbl, profiling_num

# %%
# Análisis univariado var numérica
profiling_num(d_star_wars)

# %%
profiling_num(d_star_wars['birth_year'])

# %%
# Análisis univariado var categórica
freq_tbl(d_star_wars)

# %% [markdown]
# ¿Cómo aplicar funciones de sumarización a cada columna?

# %%
d_star_wars['height'].max()

# %%
d_star_wars['height'].mean()

# %%
print("El promedio de altura es %s y el  de la altura en mts es: %s" % (str(d_star_wars['height'].mean()), str(d_star_wars['height_mts'].mean())))

# %% [markdown]
# ### 9) ¿Cómo exportar un pandas dataframe a csv?
# (y directorio de trabajo)

# %%
d_star_wars_2.head()

# %%
#Creamos un archivo csv desde un dataframa
d_star_wars_2.to_csv('starwars_colab.csv',  sep=',', index=False)

# %%
#Bajamos el archivo
files.download('starwars_colab.csv')

# %% [markdown]
# #Ejercicios
#
# Ejercicio 1: Basado en el dataframe d_star_wars agregar una columna nueva llamada BMI y calcular el indice de masa corporal (BMI) de cada personaje (mostrar nombre y BMI) [BMI = weight (kg) / height² (m²)]

# %%
#Antes de comenzar con los ejercicios volvemos a cargar los datos
d_star_wars = pd.read_csv(filepath_or_buffer="https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv", sep=',')

#Convertimos la columna peso (mass) a valores decimales
d_star_wars['mass'] = pd.to_numeric(d_star_wars['mass'], errors='coerce')

d_star_wars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN        NaN          NaN       NaN
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#    birth_year  gender homeworld species
# 0       19BBY    male  Tatooine   Human
# 1      112BBY     NaN  Tatooine   Droid
# 2       33BBY     NaN     Naboo   Droid
# 3     41.9BBY    male  Tatooine   Human
# 4       19BBY  female  Alderaan   Human
# ..        ...     ...       ...     ...
# 82        NaN  female       NaN   Human
# 83        NaN    male       NaN   Human
# 84        NaN    none       NaN   Droid
# 85        NaN  female       NaN     NaN
# 86      46BBY  female     Naboo   Human
#
# [87 rows x 10 columns]

# %%
#Ejercicio 1

# Convertir la columna 'mass' a valores decimales
d_star_wars['mass'] = pd.to_numeric(d_star_wars['mass'], errors='coerce')

# Convertir la altura de cm a metros
d_star_wars['height_m'] = d_star_wars['height'] / 100

# Calcular el índice de masa corporal (BMI)
d_star_wars['BMI'] = d_star_wars['mass'] / (d_star_wars['height_m'] ** 2)

# Mostrar nombre y BMI de cada personaje
resultado = d_star_wars[['name', 'BMI']]
print(resultado)
# Out:
#               name        BMI
# 0   Luke Skywalker  26.027582
# 1            C-3PO  26.892323
# 2            R2-D2  34.722222
# 3      Darth Vader  33.330066
# 4      Leia Organa  21.777778
# ..             ...        ...
# 82             Rey        NaN
# 83     Poe Dameron        NaN
# 84             BB8        NaN
# 85  Captain Phasma        NaN
# 86   Padmé Amidala  16.528926
#
# [87 rows x 2 columns]

# %% [markdown]
# Ejercicio 2: Mostrar nombre, altura y peso de todos los personajes ordenardos de mayor altura a menor altura

# %%
#Ejercicio 2
# Convertir la columna 'mass' a valores decimales
d_star_wars['mass'] = pd.to_numeric(d_star_wars['mass'], errors='coerce')

# Ordenar por altura de mayor a menor
personajes_ordenados = d_star_wars[['name', 'height', 'mass']].sort_values(by='height', ascending=False)

# Mostrar nombre, altura y peso de los personajes
print(personajes_ordenados)
# Out:
#               name  height   mass
# 53     Yarael Poof   264.0    NaN
# 77         Tarfful   234.0  136.0
# 68         Lama Su   229.0   88.0
# 12       Chewbacca   228.0  112.0
# 34    Roos Tarpals   224.0   82.0
# ..             ...     ...    ...
# 81            Finn     NaN    NaN
# 82             Rey     NaN    NaN
# 83     Poe Dameron     NaN    NaN
# 84             BB8     NaN    NaN
# 85  Captain Phasma     NaN    NaN
#
# [87 rows x 3 columns]

# %% [markdown]
# Ejercicio 3: Del campo hair_color reemplazar los valores nulos por 0 (cero)

# %%
#Ejercicio 3

d_star_wars['hair_color'].fillna(0, inplace=True)
print(d_star_wars[['name', 'hair_color']].head())
# Out:
#              name hair_color
# 0  Luke Skywalker      blond
# 1           C-3PO          0
# 2           R2-D2          0
# 3     Darth Vader       none
# 4     Leia Organa      brown

# %% [markdown]
# Ejercicio 4: Listar los personajes femeninos de la raza humana.

# %%
#Ejercicio 4

personajes_femeninos_humanos = d_star_wars[(d_star_wars['gender'] == 'female') & (d_star_wars['species'] == 'Human')]

print(personajes_femeninos_humanos)
# Out:
#                   name  height  mass hair_color skin_color eye_color  \
# 4          Leia Organa   150.0  49.0      brown      light     brown
# 6   Beru Whitesun lars   165.0  75.0      brown      light      blue
# 26          Mon Mothma   150.0   NaN     auburn       fair      blue
# 40      Shmi Skywalker   163.0   NaN      black       fair     brown
# 57               Cordé   157.0   NaN      brown      light     brown
# 62               Dormé   165.0   NaN      brown      light     brown
# 70          Jocasta Nu   167.0   NaN      white       fair      blue
# 82                 Rey     NaN   NaN      brown      light     hazel
# 86       Padmé Amidala   165.0  45.0      brown      light     brown
#
#    birth_year  gender  homeworld species
# 4       19BBY  female   Alderaan   Human
# 6       47BBY  female   Tatooine   Human
# 26      48BBY  female  Chandrila   Human
# 40      72BBY  female   Tatooine   Human
# 57        NaN  female      Naboo   Human
# 62        NaN  female      Naboo   Human
# 70        NaN  female  Coruscant   Human
# 82        NaN  female        NaN   Human
# 86      46BBY  female      Naboo   Human

# %% [markdown]
# Ejercicio 5: listar todos los personajes que miden más de 2 metros.

# %%
#Ejercicio 5

personajes_altos = d_star_wars[d_star_wars['height'] > 200]

print(personajes_altos)
# Out:
#             name  height   mass hair_color    skin_color      eye_color  \
# 3    Darth Vader   202.0  136.0       none         white         yellow
# 12     Chewbacca   228.0  112.0      brown           NaN           blue
# 34  Roos Tarpals   224.0   82.0       none          grey         orange
# 35    Rugor Nass   206.0    NaN       none         green         orange
# 53   Yarael Poof   264.0    NaN       none         white         yellow
# 68       Lama Su   229.0   88.0       none          grey          black
# 69       Taun We   213.0    NaN       none          grey          black
# 76      Grievous   216.0  159.0       none  brown, white  green, yellow
# 77       Tarfful   234.0  136.0      brown         brown           blue
# 80    Tion Medon   206.0   80.0       none          grey          black
#
#    birth_year  gender homeworld   species
# 3     41.9BBY    male  Tatooine     Human
# 12     200BBY    male  Kashyyyk   Wookiee
# 34        NaN    male     Naboo    Gungan
# 35        NaN    male     Naboo    Gungan
# 53        NaN    male   Quermia  Quermian
# 68        NaN    male    Kamino  Kaminoan
# 69        NaN  female    Kamino  Kaminoan
# 76        NaN    male     Kalee   Kaleesh
# 77        NaN    male  Kashyyyk   Wookiee
# 80        NaN    male    Utapau    Pau'an

# %% [markdown]
# Ejercicio 6: calcular el peso promedio de los personajes por género. Redondear el peso a dos decimales.

# %%
#Ejercicio 6



peso_promedio_por_genero = d_star_wars.groupby('gender')['mass'].mean().round(2)

print(peso_promedio_por_genero)
# Out:
# gender
# female            54.02
# hermaphrodite       NaN
# male              81.00
# none             140.00
# Name: mass, dtype: float64

# %% [markdown]
# Ejercicio 7: Calcular la altura máxima por cada especie

# %%
#Ejercicio 7

altura_maxima_por_especie = d_star_wars.groupby('species')['height'].max()


altura_maxima_por_especie
# Out:
# species
# Aleena             79.0
# Besalisk          198.0
# Cerean            198.0
# Chagrian          196.0
# Clawdite          168.0
# Droid             200.0
# Dug               112.0
# Ewok               88.0
# Geonosian         183.0
# Gungan            224.0
# Human             202.0
# Hutt              175.0
# Iktotchi          188.0
# Kaleesh           216.0
# Kaminoan          229.0
# Kel Dor           188.0
# Mirialan          170.0
# Mon Calamari      180.0
# Muun              191.0
# Nautolan          196.0
# Neimodian         191.0
# Pau'an            206.0
# Quermian          264.0
# Rodian            173.0
# Skakoan           193.0
# Sullustan         160.0
# Tholothian        184.0
# Togruta           178.0
# Toong             163.0
# Toydarian         137.0
# Trandoshan        190.0
# Twi'lek           180.0
# Vulptereen         94.0
# Wookiee           234.0
# Xexto             122.0
# Yoda's species     66.0
# Zabrak            175.0
# Name: height, dtype: float64

# %% [markdown]
# Ejercicio 8: Calcular la cantidad de personajes que contienen ojos de color rojo

# %%
#Ejercicio 8

# Filtrar los personajes con ojos de color rojo
personajes_ojos_rojos = d_star_wars[d_star_wars['eye_color'] == 'red']

# Contar la cantidad de personajes con ojos rojos
cantidad_ojos_rojos = personajes_ojos_rojos.shape[0]

print(f"Cantidad de personajes con ojos de color rojo: {cantidad_ojos_rojos}")
# Out:
# Cantidad de personajes con ojos de color rojo: 5

# %% [markdown]
# Ejercicio 9: Mostrar los personajes que son del planeta Kamino y tienen piel de color gris

# %%
#Ejercicio 9

personajes_kamino_gris = d_star_wars[(d_star_wars['homeworld'] == 'Kamino') & (d_star_wars['skin_color'] == 'grey')]
personajes_kamino_gris
# Out:
#        name  height  mass hair_color skin_color eye_color birth_year  gender  \
# 68  Lama Su   229.0  88.0       none       grey     black        NaN    male
# 69  Taun We   213.0   NaN       none       grey     black        NaN  female
#
#    homeworld   species
# 68    Kamino  Kaminoan
# 69    Kamino  Kaminoan

# %% [markdown]
# Ejercicio 10: Mostrar los personajes que midan menos de 1 metro y que sean hombres

# %%
#Ejercicios 10
personajes_bajos_hombres = d_star_wars[(d_star_wars['height'] < 100) & (d_star_wars['gender'] == 'male')]
personajes_bajos_hombres
# Out:
#                      name  height  mass hair_color  skin_color eye_color  \
# 18                   Yoda    66.0  17.0      white       green     brown
# 28  Wicket Systri Warrick    88.0  20.0      brown       brown     brown
# 44               Dud Bolt    94.0  45.0       none  blue, grey    yellow
# 71          Ratts Tyerell    79.0  15.0       none  grey, blue       NaN
#
#    birth_year gender    homeworld         species
# 18     896BBY   male          NaN  Yoda's species
# 28       8BBY   male        Endor            Ewok
# 44        NaN   male      Vulpter      Vulptereen
# 71        NaN   male  Aleen Minor          Aleena
